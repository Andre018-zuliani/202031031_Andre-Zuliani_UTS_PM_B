# %% [markdown]
# ### Andre Zuliani
# ### 202131031

# %% [markdown]
# ### import data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# disini saya mengimport library numpy, pandas dan matplotlib agar bisa mengolah data pada jupyter notebook

# %% [markdown]
# ### Import Dataset

# %%
data = pd.read_csv('K01_heart_disease.csv') #disini saya ingin menampilkan data pada heart disease.csv yang dimana saya membuat nama variable dengan nama data
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
data.info() #data info ini untuk melihat type data pada kolom
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
data.describe() #data describe ini untuk melihat deskripsi data
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
print(data['HeartDisease'].unique()) #disini saya memberikan kolom unik pada kolom HeartDisease
# Out:
# [0 1]

# %% [markdown]
# ### Mengubah object menjadi bentuk Numerik
# #### Disini saya menginput beberapa type data object yang sudah kita preprocesseing menggunakan data.info()

# %%
from sklearn.preprocessing import LabelEncoder
for col in ['Sex','ChestPainType','FastingBS','RestingECG','ExerciseAngina', 'ST_Slope', 'HeartDisease']:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    data
    print (data['Sex'],data['ChestPainType'],data['FastingBS'],data['RestingECG'],data['ExerciseAngina'],data['ST_Slope'],data['HeartDisease'])
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 913    1
# 914    1
# 915    1
# 916    0
# 917    1
# Name: Sex, Length: 918, dtype: int32 0      ATA
# 1      NAP
# 2      ATA
# 3      ASY
# 4      NAP
#       ...
# 913     TA
# 914    ASY
# 915    ASY
# 916    ATA
# 917    NAP
# Name: ChestPainType, Length: 918, dtype: object 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 913    0
# 914    1
# 915    0
# 916    0
# 917    0
# Name: FastingBS, Length: 918, dtype: int64 0      Normal
# 1      Normal
# 2          ST
# 3      Normal
# 4      Normal
#         ...
# 913    Normal
# 914    Normal
# 915    Normal
# 916       LVH
# 917    Normal
# Name: RestingECG, Length: 918, dtype: object 0      N
# 1      N
# 2      N
# 3      Y
# 4      N
#       ..
# 913    N
# 914    N
# 915    Y
# 916    N
# 917    N
# Name: ExerciseAngina, Length: 918, dtype: object 0        Up
# 1      Flat
# 2        Up
# 3      Flat
# 4        Up
#        ...
# 913    Flat
# ...

# %%
data #disini saya menampilkan data yang sudah di olah menggunakan label Encoder
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           2
# 3     48    0              0        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              3        110          264          0           1
# 914   68    1              0        144          193          1           1
# 915   57    1              0        130          131          0           1
# 916   57    0              1        130          236          0           0
# 917   38    1              2        138          175          0           1
#
# ...

# %% [markdown]
# ### Menentukan data x dan y

# %%
x = data.drop('HeartDisease', axis = 1) #Disini saya menginput kolom HeartDisease pada variable x dan y
y = data['HeartDisease']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state =0)

# %%
from sklearn.neighbors import KNeighborsClassifier #disini saya mengimport KNegihborsClassifier untuk pemodelan KNN

knn = KNeighborsClassifier(n_neighbors =1)

# %% [markdown]
# ### Pemodelan KNN

# %%
knn.fit(x_train, y_train) #Mencari nilai n_Neighbors
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
print("Akurasi score sebesar: {}".format(knn.score(x_test,y_test)*100)) # disini saya menampilkan hasil akurasi score yang sebesar 67%
# Out:
# Akurasi score sebesar: 67.3913043478261
# C:\Users\ANDRE\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
